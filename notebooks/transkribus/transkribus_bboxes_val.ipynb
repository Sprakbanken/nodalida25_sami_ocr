# %%
from pathlib import Path

import pandas as pd

from samisk_ocr.transkribus.export_to_prediction_file import get_line_transcriptions
from samisk_ocr.transkribus.map_transkribus_lines_to_gt_lines import (
    find_image_with_biggest_bbox_overlap,
    line_image_dir_to_urn_line_bbox_df,
)
from samisk_ocr.utils import image_stem_to_pageurn_line_bbox

p1 = Path("../../data/transkribus_exports/predictions/val_set/our_line_level_layout_w_lm")
p2 = Path("../../data/transkribus_exports/predictions/val_set/our_line_level_layout_wo_lm")

gt_image_dir = Path("../../data/samisk_ocr_dataset/val")
gt_df = line_image_dir_to_urn_line_bbox_df(image_dir=gt_image_dir)

gt_df_metadata = pd.read_csv("../../data/samisk_ocr_dataset/val/_metadata.csv")

gt_df = gt_df_metadata.merge(gt_df, left_on=["file_name", "line"], right_on=["image", "line"])
assert len(gt_df_metadata) == len(gt_df)

example_bbox_suffix = "_0248_0393_1731_0416"

diff_dfs = []
gt_diff = None
for p in [p1, p2]:
    print(p.name)
    for model_dir in p.iterdir():
        if model_dir.name == "old":
            continue
        prediction_df = get_line_transcriptions(model_dir, keep_source_imgs=True)

        transkribus_image_stems = prediction_df.image.apply(lambda x: Path(x).stem)
        page_urns, lines, bboxes = zip(
            *transkribus_image_stems.apply(image_stem_to_pageurn_line_bbox)
        )
        prediction_df["page_urn"] = page_urns
        prediction_df["line"] = lines
        prediction_df["bbox"] = bboxes

        df = gt_df.merge(prediction_df, on=["page_urn", "line", "bbox"])

        df_diff = prediction_df.merge(
            gt_df, on=["page_urn", "line", "bbox"], how="outer", indicator=True
        )
        df_diff = df_diff[df_diff["_merge"] == "left_only"].drop(columns=["_merge"])[
            ["transcription", "page_urn", "line", "bbox", "source_image"]
        ]
        diff_dfs.append(df_diff)

        print(
            f"\n{model_dir.name}:\n\t Antall rader med ulik bbox {len(df_diff)} av {len(gt_df)}  ({round((len(df_diff)/len(gt_df)*100),2)}%)\n"
        )

        for page_urn, df_ in df_diff.groupby("page_urn"):
            print(f"\t\t Sideurn: {page_urn}\n\t\t Antall linjebokser forskjellig: {len(df_)}")
# Out:
# our_line_level_layout_w_lm
#
# smi_nor:
# 	 Antall rader med ulik bbox 78 av 2035  (3.83%)
#
# 		 Sideurn: URN_NBN_no-nb_digibok_2014022106099_0059
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2014030408001_0022
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2016030148021_0007
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2017112948005_0032
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2018062248001_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000023167_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000024690_0006
# 		 Antall linjebokser forskjellig: 22
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_001_null
# 		 Antall linjebokser forskjellig: 9
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_002_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_004_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_005_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_006_null
# 		 Antall linjebokser forskjellig: 25
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_007_null
# 		 Antall linjebokser forskjellig: 2
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_008_null
# 		 Antall linjebokser forskjellig: 7
#
# smi_ub:
# 	 Antall rader med ulik bbox 78 av 2035  (3.83%)
#
# 		 Sideurn: URN_NBN_no-nb_digibok_2014022106099_0059
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2014030408001_0022
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2016030148021_0007
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2017112948005_0032
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2018062248001_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000023167_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000024690_0006
# 		 Antall linjebokser forskjellig: 22
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_001_null
# 		 Antall linjebokser forskjellig: 9
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_002_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_004_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_005_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_006_null
# 		 Antall linjebokser forskjellig: 25
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_007_null
# 		 Antall linjebokser forskjellig: 2
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_008_null
# 		 Antall linjebokser forskjellig: 7
#
# smi:
# 	 Antall rader med ulik bbox 78 av 2035  (3.83%)
#
# 		 Sideurn: URN_NBN_no-nb_digibok_2014022106099_0059
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2014030408001_0022
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2016030148021_0007
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2017112948005_0032
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2018062248001_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000023167_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000024690_0006
# 		 Antall linjebokser forskjellig: 22
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_001_null
# 		 Antall linjebokser forskjellig: 9
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_002_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_004_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_005_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_006_null
# 		 Antall linjebokser forskjellig: 25
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_007_null
# 		 Antall linjebokser forskjellig: 2
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_008_null
# 		 Antall linjebokser forskjellig: 7
#
# smi_pred:
# 	 Antall rader med ulik bbox 78 av 2035  (3.83%)
#
# 		 Sideurn: URN_NBN_no-nb_digibok_2014022106099_0059
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2014030408001_0022
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2016030148021_0007
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2017112948005_0032
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2018062248001_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000023167_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000024690_0006
# 		 Antall linjebokser forskjellig: 22
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_001_null
# 		 Antall linjebokser forskjellig: 9
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_002_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_004_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_005_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_006_null
# 		 Antall linjebokser forskjellig: 25
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_007_null
# 		 Antall linjebokser forskjellig: 2
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_008_null
# 		 Antall linjebokser forskjellig: 7
#
# smi_nor_pred:
# 	 Antall rader med ulik bbox 78 av 2035  (3.83%)
#
# 		 Sideurn: URN_NBN_no-nb_digibok_2014022106099_0059
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2014030408001_0022
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2016030148021_0007
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2017112948005_0032
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2018062248001_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000023167_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000024690_0006
# 		 Antall linjebokser forskjellig: 22
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_001_null
# 		 Antall linjebokser forskjellig: 9
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_002_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_004_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_005_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_006_null
# 		 Antall linjebokser forskjellig: 25
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_007_null
# 		 Antall linjebokser forskjellig: 2
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_008_null
# 		 Antall linjebokser forskjellig: 7
# our_line_level_layout_wo_lm
#
# SamiskOCR_smi_nor_pred:
# 	 Antall rader med ulik bbox 78 av 2035  (3.83%)
#
# 		 Sideurn: URN_NBN_no-nb_digibok_2014022106099_0059
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2014030408001_0022
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2016030148021_0007
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2017112948005_0032
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2018062248001_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000023167_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000024690_0006
# 		 Antall linjebokser forskjellig: 22
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_001_null
# 		 Antall linjebokser forskjellig: 9
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_002_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_004_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_005_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_006_null
# 		 Antall linjebokser forskjellig: 25
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_007_null
# 		 Antall linjebokser forskjellig: 2
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_008_null
# 		 Antall linjebokser forskjellig: 7
#
# SamiskOCR_smi:
# 	 Antall rader med ulik bbox 78 av 2035  (3.83%)
#
# 		 Sideurn: URN_NBN_no-nb_digibok_2014022106099_0059
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2014030408001_0022
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2016030148021_0007
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2017112948005_0032
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2018062248001_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000023167_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000024690_0006
# 		 Antall linjebokser forskjellig: 22
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_001_null
# 		 Antall linjebokser forskjellig: 9
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_002_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_004_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_005_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_006_null
# 		 Antall linjebokser forskjellig: 25
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_007_null
# 		 Antall linjebokser forskjellig: 2
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_008_null
# 		 Antall linjebokser forskjellig: 7
#
# SamiskOCR_smi_pred:
# 	 Antall rader med ulik bbox 78 av 2035  (3.83%)
#
# 		 Sideurn: URN_NBN_no-nb_digibok_2014022106099_0059
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2014030408001_0022
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2016030148021_0007
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2017112948005_0032
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2018062248001_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000023167_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000024690_0006
# 		 Antall linjebokser forskjellig: 22
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_001_null
# 		 Antall linjebokser forskjellig: 9
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_002_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_004_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_005_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_006_null
# 		 Antall linjebokser forskjellig: 25
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_007_null
# 		 Antall linjebokser forskjellig: 2
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_008_null
# 		 Antall linjebokser forskjellig: 7
#
# SamiskOCR_smi_nor:
# 	 Antall rader med ulik bbox 78 av 2035  (3.83%)
#
# 		 Sideurn: URN_NBN_no-nb_digibok_2014022106099_0059
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2014030408001_0022
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2016030148021_0007
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2017112948005_0032
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2018062248001_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000023167_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000024690_0006
# 		 Antall linjebokser forskjellig: 22
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_001_null
# 		 Antall linjebokser forskjellig: 9
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_002_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_004_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_005_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_006_null
# 		 Antall linjebokser forskjellig: 25
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_007_null
# 		 Antall linjebokser forskjellig: 2
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_008_null
# 		 Antall linjebokser forskjellig: 7
#
# SamiskOCR_smi_ub:
# 	 Antall rader med ulik bbox 78 av 2035  (3.83%)
#
# 		 Sideurn: URN_NBN_no-nb_digibok_2014022106099_0059
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2014030408001_0022
# 		 Antall linjebokser forskjellig: 3
# 		 Sideurn: URN_NBN_no-nb_digibok_2016030148021_0007
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2017112948005_0032
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_digibok_2018062248001_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000023167_0026
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: URN_NBN_no-nb_pliktmonografi_000024690_0006
# 		 Antall linjebokser forskjellig: 22
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_001_null
# 		 Antall linjebokser forskjellig: 9
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_002_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_004_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_005_null
# 		 Antall linjebokser forskjellig: 1
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_006_null
# 		 Antall linjebokser forskjellig: 25
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_007_null
# 		 Antall linjebokser forskjellig: 2
# 		 Sideurn: no-nb_digavis_samiaigi_null_null_19851014_6_65_1-1_008_null
# 		 Antall linjebokser forskjellig: 7

# %%
for i in range(len(diff_dfs)):
    assert all(diff_dfs[i - 1] == diff_dfs[i])
diff_df = diff_dfs[0]
diff_df.index = range(len(diff_df))


gt_diff = gt_df.merge(prediction_df, on=["page_urn", "line", "bbox"], how="outer", indicator=True)
gt_diff = gt_diff[gt_diff["_merge"] == "left_only"].drop(
    columns=["_merge", "image_y", "transcription", "source_image", "image_x"]
)

gt_diff["image"] = gt_diff.file_name
gt_diff.index = range(len(gt_diff))
assert len(diff_df) == len(gt_diff)

for tup in diff_df.itertuples():
    diff_df.at[tup.Index, "gt_image"] = find_image_with_biggest_bbox_overlap(
        bbox=tup.bbox, other_df=gt_diff
    )

diff_df = diff_df.merge(
    gt_diff, left_on="gt_image", right_on="file_name", suffixes=["_transkribus", "_gt"]
)

# %%
from PIL import Image

p = Path(
    "../../data/transkribus_exports/predictions/val_set/our_line_level_layout_w_lm/smi_nor_pred"
)

for tup in diff_df.itertuples():
    print(f"GT box               {tup.bbox_gt}")
    print(f"Transkribus box      {tup.bbox_transkribus}")

    print(f"Annotation: {tup.text}")
    print(f"Transcription: {tup.transcription}")

    # img = Image.open(p / tup.source_image)
    # img_pred = img.crop(tup.bbox_transkribus)
    # img_gt = img.crop(tup.bbox_gt)

    # display(img_gt)
    # display(img_pred)

    print("\n----\n")
# Out:
# GT box               Bbox(xmin=248, ymin=390, xmax=1731, ymax=421)
# Transkribus box      Bbox(xmin=248, ymin=393, xmax=1731, ymax=416)
# Annotation: SÁMI ALLASKUVLA JA ROMSSA UNIVERSITEHTA
# Transcription: viessu
#
# ----
#
# GT box               Bbox(xmin=243, ymin=658, xmax=2141, ymax=687)
# Transkribus box      Bbox(xmin=243, ymin=663, xmax=2141, ymax=686)
# Annotation: Muhtun čuolmmat sámi cealkkaoahpas
# Transcription: -
#
# ----
#
# GT box               Bbox(xmin=2140, ymin=3641, xmax=2237, ymax=3668)
# Transkribus box      Bbox(xmin=2140, ymin=3643, xmax=2237, ymax=3666)
# Annotation: 59
# Transcription: 2
#
# ----
#
# GT box               Bbox(xmin=305, ymin=1431, xmax=2155, ymax=1515)
# Transkribus box      Bbox(xmin=305, ymin=1450, xmax=2155, ymax=1515)
# Annotation: – Na mahtâkkis lijjim leŋgiđ, o-oo sodeháá nelgikumppi... já meid toh-uv-,
# Transcription: – Na mahtâkkis lijjim leŋgiđ, o-oo sodeháá nelgikumppi... já meid toh-uv-
#
# ----
#
# GT box               Bbox(xmin=307, ymin=1570, xmax=2160, ymax=1673)
# Transkribus box      Bbox(xmin=307, ymin=1585, xmax=2160, ymax=1659)
# Annotation: – Tiäđám mun-uv maidnii... áhh-áhh, Äijih tot lii... ijge mihheen eres...
# Transcription: – Tiäđám mun-uv maidnii... áhh-áhh, Aijih tot lii... ijge mihheen eres...
#
# ----
#
# GT box               Bbox(xmin=314, ymin=2489, xmax=2167, ymax=2604)
# Transkribus box      Bbox(xmin=314, ymin=2493, xmax=2167, ymax=2589)
# Annotation: – jos vala ohtii selvâniččim... jiem kale innig riemâččii... aainâskin
# Transcription: – jos vala ohtii selvâniččim... jiem kale innig riemâččii... aainâskin
#
# ----
#
# GT box               Bbox(xmin=1108, ymin=206, xmax=2161, ymax=248)
# Transkribus box      Bbox(xmin=1108, ymin=206, xmax=2161, ymax=237)
# Annotation: Fágajoavkku evttohusat
# Transcription: ađaloavkku evttohusat
#
# ----
#
# GT box               Bbox(xmin=2285, ymin=4190, xmax=2673, ymax=4219)
# Transkribus box      Bbox(xmin=2285, ymin=4190, xmax=2673, ymax=4215)
# Annotation: Biejvvegæjnno 2
# Transcription: Btejvvegæjrtrto 2
#
# ----
#
# GT box               Bbox(xmin=361, ymin=1609, xmax=2426, ymax=1735)
# Transkribus box      Bbox(xmin=361, ymin=1614, xmax=2426, ymax=1735)
# Annotation: – Maid? sun imâštâlâi. Tom sun tieđij, et Haŋgal ij lamaš tom
# Transcription: – Maid? sun imâštâlâi. Tom sun tieđij, et Haŋgal ij lamaš tom
#
# ----
#
# GT box               Bbox(xmin=176, ymin=3983, xmax=592, ymax=4013)
# Transkribus box      Bbox(xmin=176, ymin=3983, xmax=592, ymax=4009)
# Annotation: sommerles_aarjel.indd 26
# Transcription: sommerles aarielindd 26
#
# ----
#
# GT box               Bbox(xmin=2129, ymin=551, xmax=2944, ymax=594)
# Transkribus box      Bbox(xmin=2129, ymin=551, xmax=2944, ymax=590)
# Annotation: huvvo atnit fuođđariid mat leat heivehuvvon
# Transcription: huvvo atnit fuođđariid mat leat heivehuvvon
#
# ----
#
# GT box               Bbox(xmin=2129, ymin=720, xmax=2665, ymax=760)
# Transkribus box      Bbox(xmin=2129, ymin=720, xmax=2665, ymax=754)
# Annotation: leat heivehuvvon bohccuide.
# Transcription: leat heivehuvvon bohccuide.
#
# ----
#
# GT box               Bbox(xmin=1850, ymin=3037, xmax=2478, ymax=3091)
# Transkribus box      Bbox(xmin=1850, ymin=3037, xmax=2478, ymax=3085)
# Annotation: VÁLLJET LIIGEFUOĐĐARA
# Transcription: VALLJET LIIGEFUOĐĐARA
#
# ----
#
# GT box               Bbox(xmin=547, ymin=3109, xmax=1743, ymax=3163)
# Transkribus box      Bbox(xmin=547, ymin=3109, xmax=1743, ymax=3157)
# Annotation: de sáhttá stuora oassi fuođđaris mannat duššai go
# Transcription: de sáhttá stuora oassi fuođđaris mannat duššái go
#
# ----
#
# GT box               Bbox(xmin=1832, ymin=3109, xmax=3022, ymax=3163)
# Transkribus box      Bbox(xmin=1832, ymin=3109, xmax=3022, ymax=3157)
# Annotation: Olu boazodolliin leat buorit vásáhusat biebmamiin
# Transcription: Olu boazodolliin leat buorit vásáhusat biebmamiin
#
# ----
#
# GT box               Bbox(xmin=1838, ymin=3252, xmax=3016, ymax=3310)
# Transkribus box      Bbox(xmin=1838, ymin=3252, xmax=3016, ymax=3300)
# Annotation: niiguin dahje suoidnespáppaiguin. Álggos háddjejuv-
# Transcription: niiguin dahje suoidnespáppaiguin. Álggos háddjejuv-
#
# ----
#
# GT box               Bbox(xmin=1844, ymin=3329, xmax=3016, ymax=3377)
# Transkribus box      Bbox(xmin=1844, ymin=3329, xmax=3016, ymax=3377)
# Annotation: vojit suoinnit viidát, vai bohccot ádjánit daid borrat
# Transcription: vojit suoinnit viidát, vai bohccot ádjánit daid borrat
#
# ----
#
# GT box               Bbox(xmin=565, ymin=3327, xmax=1737, ymax=3381)
# Transkribus box      Bbox(xmin=565, ymin=3332, xmax=1737, ymax=3381)
# Annotation: Olu boazodoallit atnet stuora plastihkka fuođargáriid
# Transcription: otu boazodoallit atnet stuora plastihkka fuođargáriid
#
# ----
#
# GT box               Bbox(xmin=559, ymin=3397, xmax=1755, ymax=3452)
# Transkribus box      Bbox(xmin=559, ymin=3397, xmax=1755, ymax=3446)
# Annotation: maidda leat bijahan áissáid vai sáhttet skuhteriiguin
# Transcription: maidda leat bijahan áissáid vai sáhttet skuhteriiguin
#
# ----
#
# GT box               Bbox(xmin=1844, ymin=3400, xmax=3022, ymax=3454)
# Transkribus box      Bbox(xmin=1844, ymin=3400, xmax=3022, ymax=3448)
# Annotation: dan botta go fápmofuođar buktojuvvo. Ovdamunni
# Transcription: dan botta go fápmofuođar buktojuvvo. Ovdamunni
#
# ----
#
# GT box               Bbox(xmin=547, ymin=3472, xmax=779, ymax=3526)
# Transkribus box      Bbox(xmin=547, ymin=3477, xmax=779, ymax=3526)
# Annotation: geasehit.
# Transcription: geasehit.
#
# ----
#
# GT box               Bbox(xmin=1832, ymin=3543, xmax=3028, ymax=3597)
# Transkribus box      Bbox(xmin=1832, ymin=3549, xmax=3028, ymax=3597)
# Annotation: nu go suinniiguin dahje suoidnespáppaiguin (mat leat
# Transcription: nu go suinniiguin dahje suoidnespáppaiguin (mat leat
#
# ----
#
# GT box               Bbox(xmin=2140, ymin=3641, xmax=2237, ymax=3668)
# Transkribus box      Bbox(xmin=1838, ymin=3620, xmax=3010, ymax=3668)
# Annotation: 59
# Transcription: árrat láddjejuvvon ja main lea buorre kvalitehta), lea
#
# ----
#
# GT box               Bbox(xmin=559, ymin=3828, xmax=1743, ymax=3887)
# Transkribus box      Bbox(xmin=559, ymin=3828, xmax=1743, ymax=3883)
# Annotation: čázi danne go gáhkirat jođánit nuoskkidit muohttaga.
# Transcription: čázi danne go gáhkirat jođánit nuoskkidit muohttaga.
#
# ----
#
# GT box               Bbox(xmin=1838, ymin=3835, xmax=3016, ymax=3888)
# Transkribus box      Bbox(xmin=1838, ymin=3835, xmax=3016, ymax=3883)
# Annotation: maid lodjuda bohcco ja dat ádjána guhkit livvadit ja
# Transcription: maid lodjuda bohcco ja dat ádjána guhkit livvadit ja
#
# ----
#
# GT box               Bbox(xmin=559, ymin=3899, xmax=1743, ymax=3960)
# Transkribus box      Bbox(xmin=559, ymin=3899, xmax=1743, ymax=3954)
# Annotation: Buoremus livččii jus golggašii jogaš biebmanbáikki
# Transcription: Buoremus livččii jus golggašii jogaš biebmanbáikki
#
# ----
#
# GT box               Bbox(xmin=1832, ymin=3977, xmax=2927, ymax=4031)
# Transkribus box      Bbox(xmin=1832, ymin=3977, xmax=2927, ymax=4025)
# Annotation: boazu oažžu doarvái biepmu vai bissu vuoimmis.
# Transcription: boazu oažžu doarvái biepmu vai bissu vuoimmis.
#
# ----
#
# GT box               Bbox(xmin=565, ymin=3976, xmax=1737, ymax=4031)
# Transkribus box      Bbox(xmin=565, ymin=3982, xmax=1737, ymax=4031)
# Annotation: čađa. Vállje fal dakkár eatnama gokko čáhci golgá
# Transcription: čađa. Vállje fal dakkár eatnama gokko čáhci golgá
#
# ----
#
# GT box               Bbox(xmin=553, ymin=4119, xmax=1737, ymax=4174)
# Transkribus box      Bbox(xmin=553, ymin=4119, xmax=1737, ymax=4168)
# Annotation: njuoskka ja duolvva. Dasa lassin berre bohccuin
# Transcription: njuoskka ja duolvva. Dasa lassin berre bohccuin
#
# ----
#
# GT box               Bbox(xmin=2285, ymin=4190, xmax=2673, ymax=4219)
# Transkribus box      Bbox(xmin=1832, ymin=4192, xmax=3016, ymax=4240)
# Annotation: Biejvvegæjnno 2
# Transcription: suoidnespáppat buori kvalitehtas báikkálaččat
#
# ----
#
# GT box               Bbox(xmin=565, ymin=4262, xmax=1749, ymax=4317)
# Transkribus box      Bbox(xmin=565, ymin=4268, xmax=1749, ymax=4317)
# Annotation: Bohccot dárbbašit eambbo juhkančázi go biepmat
# Transcription: Bohccot dárbbašit eambbo juhkančázi go biepmat
#
# ----
#
# GT box               Bbox(xmin=555, ymin=4616, xmax=747, ymax=4642)
# Transkribus box      Bbox(xmin=555, ymin=4617, xmax=747, ymax=4641)
# Annotation: NIBIO POP
# Transcription: NIBIO POP
#
# ----
#
# GT box               Bbox(xmin=2865, ymin=499, xmax=4029, ymax=528)
# Transkribus box      Bbox(xmin=2865, ymin=501, xmax=4029, ymax=527)
# Annotation: Mitsubishi Lanzer F 1250 GLX
# Transcription: pre-
#
# ----
#
# GT box               Bbox(xmin=2870, ymin=615, xmax=4032, ymax=644)
# Transkribus box      Bbox(xmin=2870, ymin=618, xmax=4032, ymax=644)
# Annotation: metallic 1983 mod. vuvdojuvvo. Gárvásit registre-
# Transcription: 1400.0700 2009.
#
# ----
#
# GT box               Bbox(xmin=2869, ymin=687, xmax=3742, ymax=716)
# Transkribus box      Bbox(xmin=2869, ymin=688, xmax=3742, ymax=716)
# Annotation: rejuvvon máksá dat 75.000,- ruvnna.
# Transcription: 1900 Marsa dat 79.000,-uvra.
#
# ----
#
# GT box               Bbox(xmin=2869, ymin=773, xmax=3926, ymax=806)
# Transkribus box      Bbox(xmin=2869, ymin=774, xmax=3926, ymax=806)
# Annotation: Biila lea áibbas ođas ja ii leat vuddjojuvvon.
# Transcription: ma lea aibbas ođas ja icat vudujouvor-
#
# ----
#
# GT box               Bbox(xmin=2874, ymin=866, xmax=4036, ymax=898)
# Transkribus box      Bbox(xmin=2874, ymin=867, xmax=4036, ymax=893)
# Annotation: Riŋge (084) 66 404 ovdal 15.30 ja (084) 66 792
# Transcription: 2023:00.000
#
# ----
#
# GT box               Bbox(xmin=2871, ymin=936, xmax=3197, ymax=962)
# Transkribus box      Bbox(xmin=2871, ymin=936, xmax=3197, ymax=961)
# Annotation: maŋŋá 15.30.
# Transcription: 11181174 13:30.
#
# ----
#
# GT box               Bbox(xmin=804, ymin=1112, xmax=2601, ymax=1161)
# Transkribus box      Bbox(xmin=804, ymin=1115, xmax=2601, ymax=1138)
# Annotation: 65. nr. vuossárgga golggotmanu 14. b. 1985 – 7. jahkegeardi.
# Transcription: ovt ni: Vuossargga gorgŋen
#
# ----
#
# GT box               Bbox(xmin=361, ymin=1609, xmax=2426, ymax=1735)
# Transkribus box      Bbox(xmin=160, ymin=1594, xmax=3106, ymax=1891)
# Annotation: – Maid? sun imâštâlâi. Tom sun tieđij, et Haŋgal ij lamaš tom
# Transcription: Suvra ii doarjjo ovdaolbmo
#
# ----
#
# GT box               Bbox(xmin=702, ymin=6122, xmax=2653, ymax=6301)
# Transkribus box      Bbox(xmin=702, ymin=6130, xmax=2653, ymax=6301)
# Annotation: Áidna sámegiel áviisa
# Transcription: Áidna sámegiel áviisa
#
# ----
#
# GT box               Bbox(xmin=3451, ymin=696, xmax=4240, ymax=839)
# Transkribus box      Bbox(xmin=3451, ymin=696, xmax=4240, ymax=835)
# Annotation: Sámiráđđi meannuda
# Transcription: Sámiráđđi meannuda
#
# ----
#
# GT box               Bbox(xmin=248, ymin=390, xmax=1731, ymax=421)
# Transkribus box      Bbox(xmin=122, ymin=339, xmax=4050, ymax=667)
# Annotation: SÁMI ALLASKUVLA JA ROMSSA UNIVERSITEHTA
# Transcription: Sámi oainnut TV-2 čilgehusas
#
# ----
#
# GT box               Bbox(xmin=1808, ymin=4213, xmax=2548, ymax=4326)
# Transkribus box      Bbox(xmin=1808, ymin=4213, xmax=2548, ymax=4315)
# Annotation: Stormo duođašta sámi radioi ah-
# Transcription: Stormo duođašta sámi radioi ah-
#
# ----
#
# GT box               Bbox(xmin=1352, ymin=3107, xmax=2743, ymax=3209)
# Transkribus box      Bbox(xmin=1352, ymin=3107, xmax=2743, ymax=3194)
# Annotation: mark, 9800 Vadsø i konvolutt merket "stilling 33/85" innen 5
# Transcription: mark, 9800 Vadsø i konvolutt merket "stilling 33/85- innen 5
#
# ----
#
# GT box               Bbox(xmin=185, ymin=3898, xmax=540, ymax=3997)
# Transkribus box      Bbox(xmin=185, ymin=3898, xmax=540, ymax=3997)
# Annotation: šjoga mihttui.
# Transcription: šjoga mihttui.
#
# ----
#
# GT box               Bbox(xmin=1374, ymin=3889, xmax=2725, ymax=3994)
# Transkribus box      Bbox(xmin=1374, ymin=3898, xmax=2725, ymax=3994)
# Annotation: Nærmere opplysninger fåes ved å ringe styrer, tlf. (084)
# Transcription: Nærmere opplysninger fåes ved å ringe styrer, tlf. (084
#
# ----
#
# GT box               Bbox(xmin=1370, ymin=4313, xmax=2731, ymax=4409)
# Transkribus box      Bbox(xmin=1370, ymin=4313, xmax=2731, ymax=4397)
# Annotation: Ved psykiatrisk poliklinikk er stilling, som sykepleiekonsu-
# Transcription: Ved psykiatrisk poliklinikk er stilling som sykepleiekonsu-
#
# ----
#
# GT box               Bbox(xmin=2821, ymin=4355, xmax=4182, ymax=4451)
# Transkribus box      Bbox(xmin=2821, ymin=4355, xmax=4182, ymax=4448)
# Annotation: 1/1 still., evt. 2 halve still., fast, er ledig f.o.m. 1.1.86 under
# Transcription: 1/1 still., evt. 2 halve still., fast, er ledig f.0.m. 1.1.86 undet
#
# ----
#
# GT box               Bbox(xmin=2806, ymin=4430, xmax=4185, ymax=4552)
# Transkribus box      Bbox(xmin=2806, ymin=4430, xmax=4185, ymax=4549)
# Annotation: forutsetning godkjenning. Still.kode: 7076. Ltr. 9 - 16, avh.
# Transcription: forutsetning godkjenning. Still.kode: 7076. Ltr. 9 – 16, avh.
#
# ----
#
# GT box               Bbox(xmin=197, ymin=4680, xmax=955, ymax=4791)
# Transkribus box      Bbox(xmin=197, ymin=4680, xmax=955, ymax=4791)
# Annotation: golbma ulbmila: almmuhtit mo
# Transcription: golbma ulbmila: almmuhtit mo
#
# ----
#
# GT box               Bbox(xmin=1367, ymin=4675, xmax=2740, ymax=4737)
# Transkribus box      Bbox(xmin=1367, ymin=4689, xmax=2740, ymax=4737)
# Annotation: og konsultasjon overfor den kommunale helsetjeneste og
# Transcription: og konsultasjon overfor den kommunale helsetjeneste
#
# ----
#
# GT box               Bbox(xmin=1364, ymin=4675, xmax=2746, ymax=4791)
# Transkribus box      Bbox(xmin=1364, ymin=4689, xmax=2740, ymax=4788)
# Annotation: institusjonene i regionen. Poliklinikken arbeider forøvrig
# Transcription: institusjonene i regionen. Poliklinikken arbeider forøvrig
#
# ----
#
# GT box               Bbox(xmin=2800, ymin=4770, xmax=3412, ymax=4845)
# Transkribus box      Bbox(xmin=2800, ymin=4770, xmax=3412, ymax=4845)
# Annotation: innen 11. november 1985.
# Transcription: innen 11. november 1985
#
# ----
#
# GT box               Bbox(xmin=1364, ymin=4773, xmax=2755, ymax=4869)
# Transkribus box      Bbox(xmin=1364, ymin=4782, xmax=2755, ymax=4866)
# Annotation: etter prinsipper om desentralisert psykiatri og stillingen gir
# Transcription: etter prinsipper om desentralisert psykiatri og stillingen gir
#
# ----
#
# GT box               Bbox(xmin=1378, ymin=4866, xmax=2731, ymax=4943)
# Transkribus box      Bbox(xmin=1378, ymin=4883, xmax=2731, ymax=4943)
# Annotation: Porsanger Helsetun har egen psykiatrisk avdeling som
# Transcription: Porsanger Helsetun har egen psykiatrisk avdeling som
#
# ----
#
# GT box               Bbox(xmin=2815, ymin=5283, xmax=4194, ymax=5379)
# Transkribus box      Bbox(xmin=2815, ymin=5292, xmax=4194, ymax=5379)
# Annotation: Skolens automatiseringstekniske linje ble opprettet 1983
# Transcription: Skolens automatiseringstekniske linje ble opprettet 1983
#
# ----
#
# GT box               Bbox(xmin=1355, ymin=5370, xmax=1666, ymax=5466)
# Transkribus box      Bbox(xmin=1355, ymin=5370, xmax=1666, ymax=5466)
# Annotation: Jordmor
# Transcription: Jordmor
#
# ----
#
# GT box               Bbox(xmin=2817, ymin=5364, xmax=4134, ymax=5436)
# Transkribus box      Bbox(xmin=2817, ymin=5379, xmax=4134, ymax=5433)
# Annotation: og er tidsmessig utstyrt. Fra august 1986 får linjen også nye
# Transcription: og er tidsmessig utstyrt. Fra august 1986 får linjen ogsån
#
# ----
#
# GT box               Bbox(xmin=2811, ymin=5424, xmax=4131, ymax=5477)
# Transkribus box      Bbox(xmin=2811, ymin=5430, xmax=4131, ymax=5474)
# Annotation: og tidsmessige lokaler. Det er opprettet samarbeid med
# Transcription: og tidsmessige lokaler. Det er opprettet samarbeid mii
#
# ----
#
# GT box               Bbox(xmin=2813, ymin=5472, xmax=4182, ymax=5564)
# Transkribus box      Bbox(xmin=2813, ymin=5474, xmax=4182, ymax=5555)
# Annotation: oljeindustrien om lærlingeplasser for elevene fra VK I:
# Transcription: olleindustrien om lærlingeplasser for elevene fra VK 1:
#
# ----
#
# GT box               Bbox(xmin=1355, ymin=5722, xmax=2266, ymax=5803)
# Transkribus box      Bbox(xmin=1355, ymin=5722, xmax=2266, ymax=5803)
# Annotation: Det stilles krav til norsk godkjenning.
# Transcription: Det stilles krav til norsk godkjenning.
#
# ----
#
# GT box               Bbox(xmin=2818, ymin=5719, xmax=4155, ymax=5806)
# Transkribus box      Bbox(xmin=2818, ymin=5728, xmax=4155, ymax=5803)
# Annotation: Kan du tiltre stillingen før 1.11.85 får du kr. 20.000,- i
# Transcription: Ran du tiltre stillingen før 1.11.85 får du kr. 20.000,-
#
# ----
#
# GT box               Bbox(xmin=1377, ymin=5851, xmax=2689, ymax=5910)
# Transkribus box      Bbox(xmin=1377, ymin=5857, xmax=2689, ymax=5907)
# Annotation: pr. år, etter ansiennitet. I tillegg kommer kompensasjon for
# Transcription: pr. ar, etter ansiennitet. I tillegg kommer kompensasjon i
#
# ----
#
# GT box               Bbox(xmin=1373, ymin=5985, xmax=2701, ymax=6083)
# Transkribus box      Bbox(xmin=1373, ymin=6000, xmax=2701, ymax=6077)
# Annotation: Alta kommune er en kommune i sterk vekst og har 14.000
# Transcription: Alta kommune er en kommune i sterk vekst og har 14.00
#
# ----
#
# GT box               Bbox(xmin=257, ymin=6042, xmax=922, ymax=6140)
# Transkribus box      Bbox(xmin=257, ymin=6048, xmax=922, ymax=6137)
# Annotation: ruovttoluotta máksit
# Transcription: ruovttoluotta máksit
#
# ----
#
# GT box               Bbox(xmin=2818, ymin=6182, xmax=4176, ymax=6245)
# Transkribus box      Bbox(xmin=2818, ymin=6182, xmax=4176, ymax=6242)
# Annotation: tlf (084) 12133. Skriftlig søknad med vitnemål og attest-
# Transcription: til. (084) 12133. Skriftlig søknad med vitnemål og attest
#
# ----
#
# GT box               Bbox(xmin=1373, ymin=6245, xmax=2761, ymax=6385)
# Transkribus box      Bbox(xmin=1373, ymin=6245, xmax=2761, ymax=6385)
# Annotation: Søknad med kopi av attester og vitnemål sendes Alta
# Transcription: Søknad med kopi av attester og vitnemål sendes Alta
#
# ----
#
# GT box               Bbox(xmin=2820, ymin=6236, xmax=3609, ymax=6295)
# Transkribus box      Bbox(xmin=2820, ymin=6245, xmax=3609, ymax=6295)
# Annotation: kopier sendes snarest til skolen.
# Transcription: kopier sendes snarest til skolen.
#
# ----
#
# GT box               Bbox(xmin=1821, ymin=106, xmax=2507, ymax=319)
# Transkribus box      Bbox(xmin=1821, ymin=106, xmax=2507, ymax=313)
# Annotation: Sámi Áigi
# Transcription: Sámi Áigi
#
# ----
#
# GT box               Bbox(xmin=1960, ymin=5203, xmax=2131, ymax=5232)
# Transkribus box      Bbox(xmin=1960, ymin=5203, xmax=2131, ymax=5229)
# Annotation: Dálki
# Transcription: Dálki
#
# ----
#
# GT box               Bbox(xmin=1065, ymin=1276, xmax=3169, ymax=1694)
# Transkribus box      Bbox(xmin=1065, ymin=1276, xmax=3169, ymax=1690)
# Annotation: gildojuvvo?
# Transcription: gildojuvvo?
#
# ----
#
# GT box               Bbox(xmin=1877, ymin=3009, xmax=2671, ymax=3130)
# Transkribus box      Bbox(xmin=1877, ymin=3009, xmax=2671, ymax=3127)
# Annotation: Go mii hálešteimmet Vengeriin
# Transcription: Go mii hálešteimmet Vengeriin
#
# ----
#
# GT box               Bbox(xmin=1800, ymin=6069, xmax=2539, ymax=6100)
# Transkribus box      Bbox(xmin=1800, ymin=6069, xmax=2539, ymax=6097)
# Annotation: Máksá dušše 200,- ru. jahkái
# Transcription: Maksa dusse 200,- ru. jahkal
#
# ----
#
# GT box               Bbox(xmin=2958, ymin=6081, xmax=3184, ymax=6108)
# Transkribus box      Bbox(xmin=2958, ymin=6081, xmax=3184, ymax=6106)
# Annotation: Namma:
# Transcription: Nanna
#
# ----
#
# GT box               Bbox(xmin=1806, ymin=6203, xmax=2718, ymax=6232)
# Transkribus box      Bbox(xmin=1806, ymin=6207, xmax=2718, ymax=6232)
# Annotation: Čalis namat dasa ja sádde midjiide:
# Transcription: Gaup hamat dasa ja sáduc nujnde
#
# ----
#
# GT box               Bbox(xmin=2964, ymin=6297, xmax=4187, ymax=6328)
# Transkribus box      Bbox(xmin=2964, ymin=6297, xmax=4187, ymax=6323)
# Annotation: (Skeŋke áviissa fulkkiide, ustibiidda, verddiide dahje earáide).
# Transcription: (skeŋke avnssa Tulkkuc, ustiondda, nu
#
# ----
#
# GT box               Bbox(xmin=1806, ymin=6334, xmax=2432, ymax=6362)
# Transkribus box      Bbox(xmin=1806, ymin=6337, xmax=2432, ymax=6362)
# Annotation: Baŋkogiro 7593.08.00376
# Transcription: Baŋkogiro 7593.08.00376
#
# ----
