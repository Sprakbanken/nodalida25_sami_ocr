# %%
from pathlib import Path

from samisk_ocr.transkribus.export_to_prediction_file import get_line_transcriptions

# Transkribus export we used to build test dataset
annotation_export = Path("../../data/transkribus_exports/check/Testsett_Samisk_OCR_nytest")
annotation_df = get_line_transcriptions(annotation_export, keep_source_imgs=True)

# Transkribus export containing transkribus model predictions on test data
prediction_export = Path("../../data/transkribus_exports/check/Testsett_Samisk_OCR_nytest_preds")
prediction_df = get_line_transcriptions(prediction_export, keep_source_imgs=True)
assert len(annotation_df) == len(prediction_df)

# %%
# Last part of image filenames contain line polygon bbox (extracted from alto-xml files)
example_bbox_suffix = "0248_0393_1731_0416"


def get_bbox(file_stem: str) -> tuple[int, int, int, int]:
    return tuple(int(e) for e in file_stem[-len(example_bbox_suffix) :].split("_"))  # type: ignore


example = prediction_df.image[0]
print(example)
get_bbox(Path(example).stem)
# Out:
# URN_NBN_no-nb_pliktmonografi_000007243_0098_000_0381_0398_2130_0486.jpg
# (381, 398, 2130, 486)

# %%
same_bboxes = annotation_df.merge(prediction_df, on="image")

print(
    f"Of {len(annotation_df)} lines, {len(same_bboxes)} have the same bbox in the prediction export as the annotation export"
)
# Out:
# Of 791 lines, 700 have the same bbox in the prediction export as the annotation export

# %%
from samisk_ocr.transkribus.map_transkribus_lines_to_gt_lines import (
    find_image_with_biggest_bbox_overlap,
)

# Find the lines where bboxes differ between annotation and prediction exports
diff = prediction_df.merge(annotation_df, on=["image", "source_image"], how="outer", indicator=True)

prediction_diff = diff[diff._merge == "left_only"].copy()
prediction_diff.index = range(len(prediction_diff))
prediction_diff["bbox"] = prediction_diff.image.apply(lambda x: get_bbox(Path(x).stem))
prediction_diff = prediction_diff.rename(columns={"transcription_x": "transcription"})


annotation_diff = diff[diff._merge == "right_only"].copy()
annotation_diff.index = range(len(annotation_diff))
annotation_diff["bbox"] = annotation_diff.image.apply(lambda x: get_bbox(Path(x).stem))
annotation_diff = annotation_diff.rename(columns={"transcription_y": "transcription"})


# Match up lines with different bboxes using maximum area overlap
prediction_diff["annotation_image"] = [""] * len(prediction_diff)

for source_image, df_ in prediction_diff.groupby(
    "source_image",
):
    annotation_df_ = annotation_diff[annotation_diff.source_image == source_image]
    annotation_df_.index = range(len(annotation_df_))
    corresponding_annotation_images = [
        find_image_with_biggest_bbox_overlap(bbox=bbox, other_df=annotation_df_)
        for bbox in df_.bbox
    ]
    prediction_diff.loc[df_.index, "annotation_image"] = corresponding_annotation_images


aligned_df = prediction_diff.merge(
    annotation_diff,
    left_on=["annotation_image", "source_image"],
    right_on=["image", "source_image"],
    suffixes=("_pred", "_gt"),
)

assert len(aligned_df) == len(prediction_diff) == len(annotation_diff)

# %%
aligned_df[["bbox_pred", "bbox_gt", "source_image"]].to_csv(
    "../../data/different_bbox_text.csv", index=False
)

# %%
from PIL import Image

# Show bbox differences
for tup in aligned_df.itertuples():
    annotation = tup.transcription_gt
    model_prediction = tup.transcription_pred

    annotation_bbox = tup.bbox_gt
    prediction_bbox = tup.bbox_pred

    print(f"Annotation: {annotation}\nModel prediction: {model_prediction}")
    print(f"\nAnnotation bbox:      {annotation_bbox}\nPrediction file bbox: {prediction_bbox}")

    # img = Image.open(annotation_export / str(tup.source_image))
    # img_gt = img.crop(annotation_bbox)
    # img_pred = img.crop(prediction_bbox)

    # display(img_gt)
    # display(img_pred)

    print("-----\n")
# Out:
# Annotation: ulmuin koijâdiđ, kost taid finnee.
# Model prediction: ulmuin koijâdiđ, kost taid finnee.
#
# Annotation bbox:      (636, 1550, 1793, 1653)
# Prediction file bbox: (636, 1550, 1793, 1643)
# -----
#
# Annotation: lam pääihist. Nube peln luovtâ, maađijpiällást, uáinojii
# Model prediction: lam pääihist. Nube peln luovtâ, maađijpiällást, uáinojii
#
# Annotation bbox:      (629, 2179, 2515, 2298)
# Prediction file bbox: (629, 2181, 2515, 2280)
# -----
#
# Annotation: kuobžâenni njurgádij. Lasâlijne oinui liihâstmin já forgâ
# Model prediction: kuobžâenni njurgádij. Lasâlijne oinui liihâstmin já forgâ
#
# Annotation bbox:      (629, 2712, 2546, 2820)
# Prediction file bbox: (629, 2717, 2546, 2820)
# -----
#
# Annotation: iiđij Sammlii Issá porthái oolâ.
# Model prediction: iiđij Sammlii Issá porthái oolâ.
#
# Annotation bbox:      (621, 2824, 1676, 2919)
# Prediction file bbox: (621, 2834, 1676, 2919)
# -----
#
# Annotation: finniiččim ruuđâ, pesâččim mäksiđ taam elleituáhtár
# Model prediction: finniiččim ruuđâ, pesâččim mäksiđ taam elleituáhtár
#
# Annotation bbox:      (622, 3029, 2442, 3136)
# Prediction file bbox: (622, 3029, 2442, 3122)
# -----
#
# Annotation: – Ledje dat vilges olbmotge julmmit, dajai
# Model prediction: – Ledje dat vilges olbmotge julmmit, dajai
#
# Annotation bbox:      (1646, 346, 2734, 468)
# Prediction file bbox: (1646, 360, 2734, 468)
# -----
#
# Annotation: eadni guhkes áiggi geažes. – Dan birra dušše
# Model prediction: eadni guhkes áiggi geažes. – Dan birra dušše
#
# Annotation bbox:      (1516, 457, 2724, 550)
# Prediction file bbox: (1516, 457, 2724, 536)
# -----
#
# Annotation: ii muitaluvvo govvaráidolasttain. Vilges ol-
# Model prediction: ii muitaluvvo govvaráidolasttain. Vilges ol-
#
# Annotation bbox:      (1516, 541, 2736, 632)
# Prediction file bbox: (1516, 551, 2736, 632)
# -----
#
# Annotation: dat geat ráhkadedje dieid govvaráidolasttaid ja
# Model prediction: dat geat ráhkadedje dieid govvaráidolasttaid ja
#
# Annotation bbox:      (1519, 1445, 2699, 1544)
# Prediction file bbox: (1519, 1445, 2699, 1537)
# -----
#
# Annotation: eai láve málet muođuid, dušše Davvi-Ame-
# Model prediction: eai láve málet muođuid, dušše Davvi-Ame-
#
# Annotation bbox:      (183, 1640, 1406, 1743)
# Prediction file bbox: (183, 1640, 1406, 1743)
# -----
#
# Annotation: Soai jorggiheigga ruoktošilljui ja eadni
# Model prediction: Soai jorggiheigga ruoktošilljui ja eadni
#
# Annotation bbox:      (1635, 1633, 2718, 1754)
# Prediction file bbox: (1635, 1647, 2718, 1754)
# -----
#
# Annotation: Davvi-Amerihká indiánaid gohčodit rukses-
# Model prediction: Davvi-Amerihká indiánaid gohčodit rukses-
#
# Annotation bbox:      (1513, 2322, 2724, 2453)
# Prediction file bbox: (1513, 2322, 2724, 2453)
# -----
#
# Annotation: áigge indiánat eai báže šat geange, málešit-
# Model prediction: áigge indiánat eai báže šat geange, málešit-
#
# Annotation bbox:      (192, 2322, 1386, 2440)
# Prediction file bbox: (192, 2340, 1386, 2440)
# -----
#
# Annotation: go šat muođuidge. Ja dalle... dallego sii
# Model prediction: go šat muođuidge. Ja dalle... dallego sii
#
# Annotation bbox:      (189, 2423, 1370, 2537)
# Prediction file bbox: (189, 2430, 1370, 2525)
# -----
#
# Annotation: bohte sin eatnamii, ráhkadedje dohko ruov-
# Model prediction: bohte sin eatnamii, ráhkadedje dohko ruov-
#
# Annotation bbox:      (183, 2628, 1395, 2728)
# Prediction file bbox: (183, 2644, 1395, 2728)
# -----
#
# Annotation: – Man ivdnásaččat mii leat?
# Model prediction: – Man ivdnásaččat mii leat?
#
# Annotation bbox:      (1653, 2638, 2394, 2749)
# Prediction file bbox: (1653, 2642, 2394, 2749)
# -----
#
# Annotation: – Mii leat várra vilgesruškadat, vielgadat
# Model prediction: – Mii leat várra vilgesruškadat, vielgadat
#
# Annotation bbox:      (1653, 2932, 2712, 3031)
# Prediction file bbox: (1653, 2932, 2712, 3031)
# -----
#
# Annotation: – Muhto dat báhče bolesiidge, dajai
# Model prediction: – Muhto dat báhče bolesiidge, dajai
#
# Annotation bbox:      (304, 2924, 1384, 3033)
# Prediction file bbox: (304, 2945, 1384, 3027)
# -----
#
# Annotation: eadni jávkkihii sisa. Son ieš bázii boardaga
# Model prediction: eadni jávkkihii sisa. Son ieš bázii boardaga
#
# Annotation bbox:      (1522, 3122, 2717, 3256)
# Prediction file bbox: (1522, 3125, 2717, 3256)
# -----
#
# Annotation: ala čohkkát. Sergio leai buktán ođđa jurdagiid
# Model prediction: ala čohkkát. Sergio leai buktán ođđa jurdagiid
#
# Annotation bbox:      (1522, 3223, 2702, 3339)
# Prediction file bbox: (1522, 3223, 2702, 3339)
# -----
#
# Annotation: – Vuoi vuoi, šuohkihii eadni ohpit. Leai
# Model prediction: – Vuoi vuoi, šuohkihii eadni ohpit. Leai
#
# Annotation bbox:      (289, 3227, 1408, 3327)
# Prediction file bbox: (289, 3232, 1408, 3327)
# -----
#
# Annotation: su millii. Duot amas gánda bohciidahtii su
# Model prediction: su millii. Duot amas gánda bohciidahttii su
#
# Annotation bbox:      (1516, 3349, 2712, 3441)
# Prediction file bbox: (1516, 3349, 2712, 3428)
# -----
#
# Annotation: STARUMA LADY
# Model prediction: STÁRUMA LADY
#
# Annotation bbox:      (724, 379, 2601, 622)
# Prediction file bbox: (724, 386, 2601, 622)
# -----
#
# Annotation: dijn. De tjåhkkidit hæhttujiv. Gulliv gå vájmmo imálasj
# Model prediction: dijn. De tjåhkkidit hæhttujiv. Gulliv gå vájmmo imálasj
#
# Annotation bbox:      (94, 1318, 1578, 1394)
# Prediction file bbox: (94, 1329, 1578, 1394)
# -----
#
# Annotation: kraesijste burhvijste guktie bovtse.»
# Model prediction: kraesijste burhvijste guktie bovtse."
#
# Annotation bbox:      (363, 2476, 1412, 2563)
# Prediction file bbox: (363, 2476, 1412, 2546)
# -----
#
# Annotation: giesaj gihtse náhkev Jakoba giedaj ja
# Model prediction: giesaj gihtse náhkev Jakoba giedaj ja
#
# Annotation bbox:      (1524, 970, 2725, 1059)
# Prediction file bbox: (1524, 983, 2725, 1059)
# -----
#
# Annotation: tjiebeda birra ja vattij sunji mállásav
# Model prediction: tjiebeda birra ja vattij sunji mállásav
#
# Annotation bbox:      (1526, 1050, 2665, 1145)
# Prediction file bbox: (1526, 1064, 2665, 1145)
# -----
#
# Annotation: maná mæhttsáj. Vuotje muhtem
# Model prediction: máná mæhttsáj. Vuotje muhtem
#
# Annotation bbox:      (184, 1214, 1193, 1310)
# Prediction file bbox: (184, 1216, 1193, 1310)
# -----
#
# Annotation: mannat áhtjes lusi, Esaua sadjáj,
# Model prediction: mannat áhtjes lusi, Esaua sadjáj,
#
# Annotation bbox:      (192, 1872, 1249, 1971)
# Prediction file bbox: (192, 1872, 1249, 1971)
# -----
#
# Annotation: Isak ittjij rat jienav dåbdå ja gåhtjoj
# Model prediction: Isak ittjij rat jienav dåbdå ja gåhtjoj
#
# Annotation bbox:      (1520, 1866, 2633, 1981)
# Prediction file bbox: (1520, 1872, 2633, 1981)
# -----
#
# Annotation: – Vielljam le guolggan rubmahav
# Model prediction: – Vielljam le guolggan rubmahav
#
# Annotation bbox:      (265, 2120, 1295, 2232)
# Prediction file bbox: (265, 2131, 1295, 2232)
# -----
#
# Annotation: garrodusáv muv badjel,
# Model prediction: garrodusáv muv badjel,
#
# Annotation bbox:      (197, 2373, 943, 2460)
# Prediction file bbox: (197, 2373, 943, 2460)
# -----
#
# Annotation: Isak ittjij suv dåbdå, dajna gå Jakoba
# Model prediction: Isak ittjij suv dåbdå, dajna gå Jakoba
#
# Annotation bbox:      (1530, 2364, 2704, 2465)
# Prediction file bbox: (1530, 2370, 2704, 2465)
# -----
#
# Annotation: buorissjivnnjedusá sadjáj låhkåt.
# Model prediction: buorissjivnnjedusá sadjáj låhkåt.
#
# Annotation bbox:      (192, 2447, 1223, 2540)
# Prediction file bbox: (192, 2460, 1223, 2540)
# -----
#
# Annotation: uđđâ noomâ-uv, mii lâi Harald. Harideijee lâi finnim noomâs juo aaibâs uccen
# Model prediction: uđđâ nooma-uv, mii lâi Harald. Harideijee lâi finnim noomâs juo aaibâs uccen
#
# Annotation bbox:      (236, 1522, 2162, 1597)
# Prediction file bbox: (236, 1522, 2162, 1591)
# -----
#
# Annotation: Mättee aalgij-uv polâstâllâđ rievâidis já jobá vuájánijdis-uv peeleest. Harideijee
# Model prediction: Mättee aalgij-uv polâstâllâđ rievidis já jobá vuájánijdis-uv peeleest. Harideijee
#
# Annotation bbox:      (245, 1938, 2164, 2030)
# Prediction file bbox: (245, 1950, 2164, 2030)
# -----
#
# Annotation: – Táát viäruvovdi haalijd tiettiđ, moh tust láá rievváid kaarrum?
# Model prediction: – Táát viäruvovdi haalijd tiettiđ, moh tust láá rievváid kaarrum?
#
# Annotation bbox:      (319, 2516, 1922, 2585)
# Prediction file bbox: (319, 2516, 1922, 2580)
# -----
#
# Annotation: – Purâmušpittááh váháš já muáddi ravžâ roopâ, iskâdim ucánjihhii
# Model prediction: – Purâmušpittááh váháš já muáddi ravžâ roopâ, iskâdim ucánjihhii
#
# Annotation bbox:      (312, 2578, 2164, 2667)
# Prediction file bbox: (312, 2578, 2164, 2658)
# -----
#
# Annotation: Ronnig lai loavdam lane laasaid, vai pyerebeht oinuuččij, maht visteh
# Model prediction: Ronnig lai loavdam lane laasaid, vai pyerebeht oinuuččij, maht visteh
#
# Annotation bbox:      (561, 2280, 3138, 2439)
# Prediction file bbox: (561, 2287, 3138, 2439)
# -----
#
# Annotation: – Tiet kal ij pyevti leđe olma olmooš, jurdaččij ronnig. Sun halidij kuittag
# Model prediction: – Tiet kal ij pyevtti leđe olma olmooš, jurdaččij ronnig. Sun halidij kuittag
#
# Annotation bbox:      (569, 2510, 3276, 2651)
# Prediction file bbox: (569, 2510, 3276, 2644)
# -----
#
# Annotation: – Kooras lai, eeđai Häcišin nieida.
# Model prediction: – Kooras lai, eeđai Häciin nieida.
#
# Annotation bbox:      (641, 1795, 1903, 1963)
# Prediction file bbox: (641, 1795, 1903, 1956)
# -----
#
# Annotation: gïelen bïjre. Dellie aaj aelhkebe nubpiem kultuvrem guarkedh.
# Model prediction: gïelen bïjre. Dellie aaj aelhkebe nubpiem kultuvrem guarkedh.
#
# Annotation bbox:      (547, 987, 2216, 1084)
# Prediction file bbox: (547, 987, 2216, 1083)
# -----
#
# Annotation: vuesehte guektiengïelen almetjidie aelhkebe jeatjah faagh lieredh,
# Model prediction: vuesehte guektiengïelen almetjidie aelhkebe jeatjah faagh lieredh,
#
# Annotation bbox:      (551, 2061, 2320, 2178)
# Prediction file bbox: (551, 2061, 2320, 2176)
# -----
#
# Annotation: Jeenebh nuepieh barkoem åadtjodh
# Model prediction: Jeenebh nuepieh barkoem åadtjodh
#
# Annotation bbox:      (731, 2404, 2119, 2583)
# Prediction file bbox: (731, 2404, 2119, 2570)
# -----
#
# Annotation: sjieh gieh saemien soptsestieh, tjaelieh jïh luhkieh.
# Model prediction: sjieh gieh saemien soptsestieh, tjaelieh jïh luhkieh.
#
# Annotation bbox:      (550, 3064, 1910, 3155)
# Prediction file bbox: (550, 3073, 1910, 3155)
# -----
#
# Annotation: – Mij vuojijm ergijguin škoovlân. Mun-uv vuoijim ohtuu 12-ihásâžžân,
# Model prediction: – Mij vuojijm ergijguin škoovlân. Mun-uv vuoijim ohtuu 12-ihásâžžân,
#
# Annotation bbox:      (402, 941, 2005, 1018)
# Prediction file bbox: (402, 941, 2005, 1012)
# -----
#
# Annotation: Ella. Škovlâ lâi čoovčâst kiiđân.
# Model prediction: Ella. Skovlâ lâi čoovčâst kiiđân.
#
# Annotation bbox:      (334, 1076, 1070, 1149)
# Prediction file bbox: (334, 1081, 1070, 1149)
# -----
#
# Annotation: – Tääl must kal lii oppeet pyeri tile porgâđ jieijân pargoiguin, povvâstâl
# Model prediction: – Tääl must kal lii oppeet pyeri tile porgâđ jieijân pargoiguin, povvâstâl
#
# Annotation bbox:      (399, 1600, 2002, 1685)
# Prediction file bbox: (399, 1611, 2002, 1685)
# -----
#
# Annotation: moh umásteh ääiđi sist. Visteest sust láá kuđâlmeh uáinusist. Toos lasseen oroh
# Model prediction: moh umásteh ääiđi sist. Visteest sust láá kuđâlmeh uáinusist. Toos lasseen oroh
#
# Annotation bbox:      (336, 1878, 2113, 1954)
# Prediction file bbox: (336, 1878, 2113, 1945)
# -----
#
# Annotation: vaibâm puásuikeččeeh läävejii leđe ko pottii čuoigân maasâd iälu kulen,
# Model prediction: vaibâm puásuikeččeeh läävejii leđe ko pottii čuoigan maasâd iälu kulen,
#
# Annotation bbox:      (336, 2744, 1956, 2818)
# Prediction file bbox: (336, 2752, 1956, 2818)
# -----
#
# Annotation: – Mun lam kal luuhâm tain nuáidikonstâkiirjijn, Jovnâ västidij.
# Model prediction: – Mun lam kal luuhâm tain nuáidikonstâkiirjijn, Jovnâ västidij.
#
# Annotation bbox:      (347, 410, 2345, 512)
# Prediction file bbox: (347, 410, 2345, 507)
# -----
#
# Annotation: – Tun uáivildâh taid ulmui čalmekäidimkiirjijd? Tot ij lah ollágin
# Model prediction: – Tun uáivildâh taid ulmui čalmekäidimkiirjijd? Tot ij lah ollágin
#
# Annotation bbox:      (352, 494, 2397, 605)
# Prediction file bbox: (352, 494, 2397, 594)
# -----
#
# Annotation: – Uáivildâh-uv tun, et tun kiävtáh telepatia muin sárnumân? Jovnâ
# Model prediction: – Uáivildâh-uv tun, et tun kiävtáh telepatia muin sárnumân? Jovnâ
#
# Annotation bbox:      (344, 665, 2432, 783)
# Prediction file bbox: (344, 673, 2432, 783)
# -----
#
# Annotation: – Kii talle lii tuu vyeimiskippáár?
# Model prediction: – Kii talle lii tuu vyeimiskippáár?
#
# Annotation bbox:      (337, 1346, 1418, 1454)
# Prediction file bbox: (337, 1349, 1418, 1454)
# -----
#
# Annotation: tast lii siemin muštooš, moin sun puáhtá tubdâđ häldeid, tâi
# Model prediction: tast lii siemin muštooš, moin sun puáhtá tubdâđ häldeid, tâi
#
# Annotation bbox:      (326, 1851, 2407, 1948)
# Prediction file bbox: (326, 1861, 2407, 1948)
# -----
#
# Annotation: – Na mut mondet Haŋgal?
# Model prediction: – Na mut mondet Haŋgal?
#
# Annotation bbox:      (341, 2276, 1181, 2369)
# Prediction file bbox: (341, 2282, 1181, 2369)
# -----
#
# Annotation: – Tondet, ko sun-uv lii kuoskâttâm suábi!
# Model prediction: – Tondet, ko sun-uv lii kuoskâttâm suábi!
#
# Annotation bbox:      (336, 2437, 1657, 2550)
# Prediction file bbox: (336, 2437, 1657, 2526)
# -----
#
# Annotation: anneeđ kieđâin, te jienâ ij innig almostum. Jovnâ ferttij vyelgiđ
# Model prediction: anneeđ kieđâin, te jienâ ij innig almostum. Jovnâ ferttij vyelgiđ
#
# Annotation bbox:      (321, 3212, 2428, 3333)
# Prediction file bbox: (321, 3212, 2428, 3312)
# -----
#
# Annotation: nommekonsulenth maehtieh nommeaamhtesem
# Model prediction: nommekonsulenth maehtieh nommeaamhtesem
#
# Annotation bbox:      (1561, 1134, 2787, 1204)
# Prediction file bbox: (1561, 1139, 2787, 1204)
# -----
#
# Annotation: saemien dajvine (saemien gïelen reeremedajvesne)
# Model prediction: saemien dajvine (saemien gïelen reeremedajvesne)
#
# Annotation bbox:      (213, 2074, 1518, 2154)
# Prediction file bbox: (213, 2078, 1518, 2154)
# -----
#
# Annotation: Dellie maajetjh gosse Alits buektehte tjelmide nïejteste luejhtedh,
# Model prediction: Dellie maajetjh gosse Alits buektehte tjelmide nïejteste luejhtedh,
#
# Annotation bbox:      (178, 277, 2515, 389)
# Prediction file bbox: (178, 299, 2515, 389)
# -----
#
# Annotation: dle aajhtsa naan gedtieh mah ånnetji dubpielisnie lovvesjeminie!
# Model prediction: dle aajhtsa naan gedtieh mah ånnetji dubpielisnie lovvesjeminie!
#
# Annotation bbox:      (178, 386, 2503, 492)
# Prediction file bbox: (178, 396, 2503, 492)
# -----
#
# Annotation: gænnah. Åejjieh raaktan savtalieh, jïh eah juelkieh vielie satnem
# Model prediction: gænnah. Aejjieh raaktan savtalieh, jïh eah juelkieh vielie satnem
#
# Annotation bbox:      (187, 1347, 2491, 1473)
# Prediction file bbox: (187, 1347, 2491, 1455)
# -----
#
# Annotation: raerieh. Jïjnjesh dejstie eatnemen baernijste mah daebpene mïnneme,
# Model prediction: raerieh. Jïjnjesh dejstie eatnemen baernijste mah daebpene mïnneme,
#
# Annotation bbox:      (171, 1800, 2687, 1931)
# Prediction file bbox: (171, 1800, 2687, 1914)
# -----
#
# Annotation: vielie gænnah buektehth soptsestidh.
# Model prediction: vielie gænnah buektehth soptsestidh.
#
# Annotation bbox:      (181, 1981, 1529, 2109)
# Prediction file bbox: (181, 1981, 1529, 2085)
# -----
#
# Annotation: – Dagke nimhtie, Alits jeahta. Dan hov lea annje guedteles gïele,
# Model prediction: – Dagke nimhtie, Alits jeahta. Dan hov lea annje guedteles gïele,
#
# Annotation bbox:      (238, 2090, 2515, 2201)
# Prediction file bbox: (238, 2090, 2515, 2196)
# -----
#
# Annotation: jïh sov njoektjeme gujht annje jårra guktie edtja jårredh. Sagki
# Model prediction: jïh sov njoektjeme gujht annje jårra guktie edtja jårredh. Sagki
#
# Annotation bbox:      (196, 2188, 2431, 2308)
# Prediction file bbox: (196, 2188, 2431, 2283)
# -----
#
# Annotation: vearrebe dejnie vaajmojne – vååjmede dan tjarki, raaktan jårra,
# Model prediction: vearrebe dejnie vaajmojne – vååjmede dan tjarki, raaktan jårra,
#
# Annotation bbox:      (181, 2271, 2439, 2411)
# Prediction file bbox: (181, 2280, 2439, 2411)
# -----
#
# Annotation: bælla nïejte sån aaj dam gåvla.
# Model prediction: bælla nïejte sån aaj dam gåvla.
#
# Annotation bbox:      (168, 2377, 1296, 2489)
# Prediction file bbox: (168, 2389, 1296, 2489)
# -----
#
# Annotation: guoli, muhto Jáhkovuonas eai lean ovttasge buđehat. Ii lean
# Model prediction: guoli, muhto Jáhkovuonas eai lean ovttasge buđehat. Ii lean
#
# Annotation bbox:      (137, 908, 1990, 1033)
# Prediction file bbox: (137, 908, 1990, 1024)
# -----
#
# Annotation: jorgalit plogain heastta maŋis ja hárvet. Bargat buđet-
# Model prediction: jorgalit plogain heastta maŋis ja hárvet. Bargat buđet-
#
# Annotation bbox:      (137, 1522, 1860, 1617)
# Prediction file bbox: (137, 1526, 1860, 1617)
# -----
#
# Annotation: Finnmárkku rittu dálvviid biekkai ja lei čoaskkis, ja stobut
# Model prediction: Finnmárkku rittu dálvviid biekkai ja lei čoaskkis, ja stobut
#
# Annotation bbox:      (146, 1904, 1999, 1990)
# Prediction file bbox: (146, 1909, 1999, 1990)
# -----
#
# Annotation: ja sáhttá ja dohkke bargat visot. Dát gal lea positiivvalaččat
# Model prediction: ja sáhttá ja dohkke bargat visot. Dát gal lea positiivvalaččat
#
# Annotation bbox:      (215, 2745, 1943, 2828)
# Prediction file bbox: (215, 2747, 1943, 2828)
# -----
#
# Annotation: daddjojuvvon, dainna oaivilin ahte buđeha sáhttá geavahit
# Model prediction: daddjojuvvon, dainna oaivilin ahte buđeha sáhttá geavahit
#
# Annotation bbox:      (211, 2829, 1946, 2944)
# Prediction file bbox: (211, 2833, 1946, 2944)
# -----
#
# Annotation: dárbahip ja máhttá åhpadit mijáv ådå ásjijt. Media tjuovvu maŋen mij
# Model prediction: dárbahip ja máhttá åhpadit mijáv ådå ásjijt. Media tjuovvu maŋen mij
#
# Annotation bbox:      (1086, 894, 2991, 1004)
# Prediction file bbox: (1086, 894, 2991, 992)
# -----
#
# Annotation: sebrudagán dáhpáduvvá, ja diedet jus ájtssá iehperievtesvuodajt sebru-
# Model prediction: sebrudagán dáhpáduvvá, ja diedet jus ájtssá iehperievtesvuodajt sebru-
#
# Annotation bbox:      (1078, 995, 3004, 1112)
# Prediction file bbox: (1078, 1004, 3004, 1112)
# -----
#
# Annotation: riektaga oasen jåhtet. Ræjdo máhtti liehket tjáppa gåvå, vuogas ul-
# Model prediction: riektaga oasen jåhtet. Ræjdo máhtti liehket tjáppa gåvå, vuogas ul-
#
# Annotation bbox:      (1088, 2157, 3010, 2288)
# Prediction file bbox: (1088, 2174, 3010, 2288)
# -----
#
# Annotation: tallijt rudáj vaj sij adni anon sijá merkajt ja logojt biktasijn, ræjdojn ja
# Model prediction: tallijt rudáj vaj sij adni anon sijá merkajt ja logojt biktasijn, ræjdojn ja
#
# Annotation bbox:      (1105, 3111, 3015, 3222)
# Prediction file bbox: (1105, 3113, 3015, 3222)
# -----
#
# Annotation: bijlajn. Reklámaj ræjdo «njáhki» mija miela sisi nåv vaj mij jáhkkep ahte
# Model prediction: bijlajn. Reklámaj ræjdo "njáhki" mija miela sisi nåv vaj mij jáhkkep ahte
#
# Annotation bbox:      (1102, 3219, 3015, 3343)
# Prediction file bbox: (1102, 3219, 3015, 3341)
# -----
#
# Annotation: ja siján li badjelasj 20 bágo majt vissjalit javlli. Guovtejagák mánájn gejn la dågålasj
# Model prediction: ja siján li badjelasj 20 bágo majt vissjalit javllii. Guovtejagák mánájn gejn la dågålasj
#
# Annotation bbox:      (235, 1100, 2336, 1182)
# Prediction file bbox: (235, 1102, 2336, 1182)
# -----
#
# Annotation: tusa ja juhtusij jiena, rubmaha lahtasa, ståhkusa, biebmo, biktasa, ulmutja, diŋga
# Model prediction: tusa ja juhtusij jiena, rubmaha lahtasa, ståhkusa, biebmo, biktasa, ulmutja, diŋga
#
# Annotation bbox:      (230, 1811, 2340, 1903)
# Prediction file bbox: (230, 1814, 2340, 1903)
# -----
#
# Annotation: 17
# Model prediction: 17
#
# Annotation bbox:      (1245, 3451, 1321, 3516)
# Prediction file bbox: (1245, 3451, 1321, 3515)
# -----
#
# Annotation: vuojnná nuore urudisájt boahtemin. Valla sån gal ij sidá rávgav
# Model prediction: vuojnná nuore urudisájt boahtemin. Valla sån gal ij sidá rávgav
#
# Annotation bbox:      (477, 870, 2159, 960)
# Prediction file bbox: (477, 888, 2159, 960)
# -----
#
# Annotation: Divna guollára giehttu rávga birra. Javlli jábbmek la dat, mij bårjås
# Model prediction: Divna guollára giehttu rávga birra. Javlli jábbmek la dat, mij bårjås
#
# Annotation bbox:      (552, 1118, 2332, 1219)
# Prediction file bbox: (552, 1127, 2332, 1219)
# -----
#
# Annotation: biráldis lahkke vantsajn ja rájgge bårjjåsijn. Dat la bahá ja várálasj.
# Model prediction: biráldis lahkke vantsajn ja rájgge bårjjåsijn. Dat la bahá ja várálasj.
#
# Annotation bbox:      (470, 1210, 2282, 1315)
# Prediction file bbox: (470, 1210, 2282, 1308)
# -----
#
# Annotation: Ingvállja l javllam, rávgga agev åhtså náginav majt maŋen
# Model prediction: Ingvállja 1 javllam, rávgga agev åhtså náginav majt maŋen
#
# Annotation bbox:      (552, 1290, 2118, 1378)
# Prediction file bbox: (552, 1299, 2118, 1378)
# -----
#
# Annotation: Nuorrejiedna rievddá. Ij så bullarda, degu nágin gænna l ilá ållo
# Model prediction: Nuorrejiedna rievddá. Ij så bullarda, degu nágin gænna l ilá ållo
#
# Annotation bbox:      (552, 1611, 2296, 1732)
# Prediction file bbox: (552, 1623, 2296, 1716)
# -----
#
# Annotation: gaskebullegievleste goerehtidh dej göökte goerehtimmiej gaskem gosse joekehtsasse vuartesje
# Model prediction: gaskebullegievleste goerehtidh dej göökte goerehtimmiej gaskem gosse joekehtsasse vuartesje
#
# Annotation bbox:      (372, 703, 2288, 770)
# Prediction file bbox: (372, 712, 2288, 770)
# -----
#
# Annotation: 2- goerehtimmine. Daah almetjh lin aaltarisnie 36–69 jaepieh gosse lin meatan SAMINOR
# Model prediction: 2- goerehtimmine. Daah almetjh lin aaltarisnie 36–69 jaepieh gosse lin meatan SÁMINOR
#
# Annotation bbox:      (367, 920, 2278, 987)
# Prediction file bbox: (367, 931, 2278, 987)
# -----
#
# Annotation: 1- jïh SAMINOR 2-goerehtimmiej gaskem. Figuvre 5 (gårroehbielesne) vuesehte, dan
# Model prediction: 1- jïh SÁMINOR 2-goerehtimmiej gaskem. Figuvre 5 (gårroehbielesne) vuesehte, dan
#
# Annotation bbox:      (374, 1568, 2289, 1641)
# Prediction file bbox: (374, 1572, 2289, 1641)
# -----
#
# Annotation: gaskebullegievlien bïjre, men gaskebullegievlie amma ånnetji vaenebe læssani dej båara-
# Model prediction: gaskebullegievlien bïjre, men gaskebullegievlie amma ånnetji vaenebe læssani dej båara-
#
# Annotation bbox:      (379, 2363, 2289, 2437)
# Prediction file bbox: (379, 2378, 2289, 2437)
# -----
